# %%
import matplotlib.pyplot as plt
import math
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib.pyplot import figure
from mpl_toolkits.mplot3d import Axes3D
from wordcloud import WordCloud

# %%
df = pd.read_csv(r"C:\Users\kyrie\ironhack\project4\cleansheet2.csv")
df
# Out:
#      Unnamed: 0       Dates      Time Choose your gender   Age  \
# 0             0  2020-08-07  12:02:00             Female  18.0
# 1             1  2020-08-07  12:04:00               Male  21.0
# 2             2  2020-08-07  12:05:00               Male  19.0
# 3             3  2020-08-07  12:06:00             Female  22.0
# 4             4  2020-08-07  12:13:00               Male  23.0
# ..          ...         ...       ...                ...   ...
# 96           96  2020-07-13  19:56:49             Female  21.0
# 97           97  2020-07-13  21:21:42               Male  18.0
# 98           98  2020-07-13  21:22:56             Female  19.0
# 99           99  2020-07-13  21:23:57             Female  23.0
# 100         100  2020-07-18  20:16:21               Male  20.0
#
#     What is your course?  Your current year of Study  What is your CGPA?  \
# 0            Engineering                           1                   3
# ...

# %%
from matplotlib.pyplot import figure

figure(figsize=(12, 6))
plt.style.use('classic')
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Your current year of Study'}>],
#        [<AxesSubplot:title={'center':'What is your CGPA?'}>,
#         <AxesSubplot:title={'center':'Marital status'}>,
#         <AxesSubplot:title={'center':'Do you have Depression?'}>],
#        [<AxesSubplot:title={'center':'Do you have Anxiety?'}>,
#         <AxesSubplot:title={'center':'Do you have Panic attack?'}>,
#         <AxesSubplot:title={'center':'Did you seek any specialist for a treatment?'}>]],
#       dtype=object)

# %%
df['What is your course?'].value_counts().plot(kind="bar",figsize=(15,7))
plt.title('Category of study')
# Out:
# Text(0.5, 1.0, 'Category of study')

# %%
count1 = 0
count0 = 0
list=[]
for i in df['Do you have Depression?']: 
    list.append(i)
  


for i in list : 
    if i == 1:
        count1+=1
    else :
        count0+=1


Depression = ['Yes', 'No']

values = [count1, count0]

plt.bar(Depression, values)

plt.title("result of the 'do you have depression' question in the student questionnary")  ;plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


df.groupby(['Choose your gender'])['What is your course?'].count().plot.bar()
plt.title('gender repartiton of the data')
# Out:
# Text(0.5, 1.0, 'gender repartiton of the data')

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['Do you have Depression?', 'Do you have Anxiety?', 'Do you have Panic attack', 'Did you seek any specialist for a treatment?'])
df.plot.box(grid='True')
plt.title('Mental problem of students')
# Out:
# Text(0.5, 1.0, 'Mental problem of students')

# %%
depr = df[df['Do you have Depression?']==1]

depr.groupby(['Age'])['Do you have Depression?'].count().plot.bar()
plt.title('repartition of depression depending on age')
# Out:
# Text(0.5, 1.0, 'repartition of depression depending on age')

# %%
data = df.groupby(['Age'])['Age'].sum()
colors = ['#4F6272', '#B7C3F3', '#DD7596', '#8EB897','#380282','#FF4500','#E50000']

plot = data.plot.pie(y='mass', figsize=(5, 5),wedgeprops = { 'linewidth' : 1, 'edgecolor' : 'white' }, colors=colors);


plt.title("Age repartition of the participants")  ;plt.show()

# %%
data = df.groupby(['Age'])['Age'].sum()
list = []
list = [i for i in data]
list

labels = [18, 19, 20,21,22,23,24]
plt.style.use('classic')
#sizes = [40, 45, 15]
sizes = list

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, shadow=True, startangle=80)

plt.title("Age of the students repartition") 

plt.show()

# %%
gender = df['Choose your gender'].value_counts()

plt.style.use('classic')
labels = ['Female', 'Male']
count = [466, 843]
fig, ax = plt.subplots()
ax.pie(count, labels=labels)
ax.axis('equal')
plt.title('gender repartiton')
plt.show()

# %%
depr.groupby(['Age'])['Do you have Depression?'].count().plot.pie()
plt.title('repartition of depression depending on age')
# Out:
# Text(0.5, 1.0, 'repartition of depression depending on age')

# %%
import matplotlib.pylab as plt
# df is a DataFrame: fetch col1 and col2 
# and drop na rows if any of the columns are NA
mydata = df[["Age", "Your current year of Study"]].dropna(how="any")
# Now plot with matplotlib
vals = mydata.values
plt.scatter(vals[:, 0], vals[:, 1])

# %%
import matplotlib.pylab as plt


df['col3'] = np.arange(len(df))*7
df.plot.scatter('Age', 'Your current year of Study', df['col3'])
plt.title('Repartition of the age of the student depending on their current year of study')
# Out:
# Text(0.5, 1.0, 'Repartition of the age of the student depending on their current year of study')

# %%
import matplotlib.pylab as plt
depr.plot.scatter('Do you have Depression?', 'Your current year of Study')
# Out:
# <AxesSubplot:xlabel='Do you have Depression?', ylabel='Your current year of Study'>

# %%
plt.scatter(vals[:, 0], vals[:, 1])

# %%
text=df['What is your course?'].values
wordcloud = WordCloud().generate(str(text))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
plt.title('courses repartition with the wordcloud librairie')
# Out:
# Text(0.5, 1.0, 'courses repartition with the wordcloud librairie')

# %%
df['What is your course?'].values
# Out:
# array(['Engineering', 'Islamic education', 'It', 'Laws', 'Mathemathics',
#        'Engineering', 'Islamic education', 'Banking studies',
#        'Human resources', 'Islamic education', 'Psychology',
#        'Engineering', 'Banking studies', 'Engineering',
#        'K Economics and Management sciences', 'Banking studies',
#        'Accounting', 'Laws', 'It', 'Marine science', 'Engineering',
#        'Engineering', 'Banking studies', 'Engineering', 'Banking studies',
#        'Banking studies', 'Engineering', 'Engineering', 'It',
#        'Banking studies', 'Business administration', 'Banking studies',
#        'Banking studies', 'Banking studies', 'It', 'Engineering', 'Laws',
#        'It', 'Islamic education', 'Engineering', 'It', 'Engineering',
#        'Islamic education', 'It', 'Taasl', 'Banking studies',
#        'Engineering', 'Engineering', 'Banking studies', 'Banking studies',
#        'Ala', 'Banking studies', 'Health', 'Engineering',
# ...
